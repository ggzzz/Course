# %% [markdown]
# <br>
# <font size="+2"> In this notebook, we will be working on questions in Colab Notebooks section in Module 1. </font>
# <br><br>

# %% [markdown]
# In this notebook, we will continue working with `city_temperature.csv` datafile; remember that the format of this datafile is the same as the temperature datafile we were using in the video, it just has many more data points because it includes temperature data for the entire world (i.e. rows).

# %% [markdown]
# <font color='#FF4500' size="+2"> To set up your DataFrame for these questions, run the cell below. </font>

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)

import os
os.chdir("/content/drive/My Drive/AIMOOC")

import pandas as pd
df2 = pd.read_csv("/content/drive/My Drive/AIMOOC/Modules/Module1/Data/city_temperature.csv")

# %%
import pandas as pd
df = pd.read_csv("./Data/city_temperature.csv")
# Out:
# /usr/local/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Questions on Visualizations

# %% [markdown]
# In this series of questions you will be deciding which datasets match each plot. Create the following cleaned up dataset called `clean`, which is the full temperature dataset without any -99 temperatures. Use the command below (run the cell below), assuming that your full dataset is saved in a DataFrame called df2.

# %%
df = df.loc[(df["AvgTemperature"] != -99)]

# %% [markdown]
# ## Question 1
#
# Create an x-y plot of the average temperature in Paris in the year 2002.

# %%
# Your code here
import matplotlib.pyplot as plt
# Out:
# Bad key text.latex.preview in file /usr/local/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file /usr/local/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.jpeg_quality in file /usr/local/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 418 ('savefig.jpeg_quality: 95       # when a jpeg is saved, the default quality parameter.')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.frameon in file /usr/local/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 421 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.level in file /usr/local/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 472 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.fileo in file /usr/local/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 473 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key keymap.all_axes in file /usr/local/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 490 ('keymap.all_axes : a                 # enable all axes')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_path in file /usr/local/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 501 ('animation.avconv_path: avconv     # Path to avconv binary. Without full path')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_args in file /usr/local/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 503 ('animation.avconv_args:            # Additional arguments to pass to avconv')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
avg_temp_in_2002_paris = df.loc[(df['Year'] == 2002) & (df['City'] == 'Paris')]['AvgTemperature']
plt.plot(avg_temp_in_2002_paris)

# %% [markdown]
# ## Question 2
#
# Create a scatter plot of the average temperature in Tokyo in the year 1996.

# %%
# Your code here
tokyo = df.loc[(df['City'] == 'Tokyo') & (df['Year'] == 1996)]
plt.scatter(range(len(tokyo)), tokyo['AvgTemperature'])

# %% [markdown]
# ## Question 3
#
# Create a histogram of the average temperature in the country Sweden in March with 10 bins.

# %%
# Your code here
sweden = df.loc[(df['Country'] == 'Sweden') & (df['Month'] == 3)]
plt.hist(sweden['AvgTemperature'], bins=10)
# Out:
# (array([  4.,  11.,  36.,  59., 125., 214., 179., 124.,  46.,   7.]),
#  array([ 9.5 , 13.79, 18.08, 22.37, 26.66, 30.95, 35.24, 39.53, 43.82,
#         48.11, 52.4 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Question 4
#
# Create a histogram of the average temperature in the country Sweden in March with 4 bins. Use the histogram to approximate the total number of data points.

# %%
# Your code here
plt.hist(sweden['AvgTemperature'], bins=4)
# Out:
# (array([ 27., 208., 459., 111.]),
#  array([ 9.5  , 20.225, 30.95 , 41.675, 52.4  ]),
#  <BarContainer object of 4 artists>)

# %% [markdown]
# ## Question 5
#
# What is the correlation between average temperature and month for the country Japan in the year 2000 and months January through July?

# %%
# Your code here
japan = df.loc[(df['Country'] == 'Japan') & (df['Month'] >= 1) & (df['Month']<=7) & (df['Year'] == 2000)]
japan.corr()
# Out:
#                    Month       Day  Year  AvgTemperature
# Month           1.000000  0.007604   NaN        0.833035
# Day             0.007604  1.000000   NaN        0.054262
# Year                 NaN       NaN   NaN             NaN
# AvgTemperature  0.833035  0.054262   NaN        1.000000

# %% [markdown]
# ## Question 6
#
# What is the correlation between average temperature and month for the country Argentina in the year 2000 and months January through July?

# %%
# Your code here
argentina = df.loc[(df['Country'] == 'Argentina') & (df['Month'] >= 1) & (df['Month']<=7) & (df['Year'] == 2000)]

argentina.corr()
# Out:
#                    Month       Day  Year  AvgTemperature
# Month           1.000000  0.007604   NaN       -0.894116
# Day             0.007604  1.000000   NaN       -0.104284
# Year                 NaN       NaN   NaN             NaN
# AvgTemperature -0.894116 -0.104284   NaN        1.000000

# %% [markdown]
# ## Question 7
#
# What is the correlation between average temperature and month for the country Colombia in the year 2000? Round to 2 decimal places.

# %%
# Your code here
colombia = df.loc[(df['Country'] == 'Colombia') & (df['Year'] == 2000)]
colombia.corr()
# Out:
#                    Month       Day  Year  AvgTemperature
# Month           1.000000  0.000691   NaN       -0.017692
# Day             0.000691  1.000000   NaN        0.032431
# Year                 NaN       NaN   NaN             NaN
# AvgTemperature -0.017692  0.032431   NaN        1.000000
